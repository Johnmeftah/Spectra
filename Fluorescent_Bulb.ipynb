# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import name 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import math

# %%
data = pd.read_csv('https://spectralworkbench.org/spectrums/latest/237869.csv')

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Compact Fluorescent Bulb Spectrum") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Average, color="black",label='average',
         linewidth=1)
plt.savefig('Compact Fluorescent Bulb Spectrum.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Compact Fluorescent Bulb Spectrum, Red Color") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Red, color="Red",label='Red', 
         linewidth=1)
plt.savefig('Compact Fluorescent Bulb Spectrum2.jpg', format='jpg', dpi=500)

# %%
data2 = np.loadtxt("https://spectralworkbench.org/spectrums/latest/237869.csv",delimiter=',',skiprows=1)
print(data)
# Out:
#      Wavelength  Average  Red  Green  Blue
# 0         232.9      0.0  0.0    0.0   0.0
# 1         233.8      0.0  0.0    0.0   0.0
# 2         234.7      0.0  0.0    0.0   0.0
# 3         235.6      0.0  0.0    0.0   0.0
# 4         236.5      0.0  0.0    0.0   0.0
# ..          ...      ...  ...    ...   ...
# 635       801.8      0.0  0.0    0.0   0.0
# 636       802.7      0.0  0.0    0.0   0.0
# 637       803.6      0.0  0.0    0.0   0.0
# 638       804.5      0.0  0.0    0.0   0.0
# 639       805.4      0.0  0.0    0.0   0.0
#
# [640 rows x 5 columns]

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Compact Fluorescent Bulb Spectrum, Average Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
averageCounts = data2[:,1]
plt.plot(wavelengthData,averageCounts,'k',label='data')
plt.savefig('Compact Fluorescent Bulb Spectrum3.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Compact Fluorescent Bulb Spectrum, Red Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
RedCounts = data2[:,2]
plt.plot(wavelengthData,RedCounts,'r',label='data')
plt.savefig('Compact Fluorescent Bulb Spectrum4.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Compact Fluorescent Bulb Spectrum, Green Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
GreenCounts = data2[:,3]
plt.plot(wavelengthData,GreenCounts,'g',label='data')
plt.savefig('Compact Fluorescent Bulb Spectrum5.jpg', format='jpg', dpi=500)

# %%
maxR = np.argmax(data2[:,2])

# %%
print(maxR)
# Out:
# 423

# %%
print(wavelengthData[423])
# Out:
# 611.9
