# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import name 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import math

# %%
data = pd.read_csv('https://spectralworkbench.org/spectrums/latest/226903.csv')

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Helium Spectrum") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Average, color="black",label='average',
         linewidth=1)
plt.savefig('Helium Spectrum.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Helium Spectrum, Red Color") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Red, color="Red",label='Red', 
         linewidth=1)
plt.savefig('Helium Spectrum1.jpg', format='jpg', dpi=500)

# %%
data2 = np.loadtxt("https://spectralworkbench.org/spectrums/latest/226903.csv",delimiter=',',skiprows=1)
print(data)
# Out:
#      Wavelength  Average    Red  Green   Blue
# 0         209.9     22.9  25.50  12.75  30.60
# 1         210.8     22.9  25.50  10.20  28.05
# 2         211.7     17.8  25.50   7.65  25.50
# 3         212.6     20.4  25.50  10.20  25.50
# 4         213.5     20.4  25.50  10.20  25.50
# ..          ...      ...    ...    ...    ...
# 635       782.8     22.9  25.50  10.20  28.05
# 636       783.7     20.4  25.50  10.20  28.05
# 637       784.6     20.4  25.50  10.20  28.05
# 638       785.5     22.9  25.50  12.75  28.05
# 639       786.4     22.9  28.05  12.75  30.60
#
# [640 rows x 5 columns]

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Helium Spectrum, Average Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
averageCounts = data2[:,1]
plt.plot(wavelengthData,averageCounts,'k',label='data')
plt.savefig('Helium Spectrum2.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Helium Spectrum, Red Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
RedCounts = data2[:,2]
plt.plot(wavelengthData,RedCounts,'r',label='data')
plt.savefig('Helium Spectrum3.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Helium Spectrum, Green Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
GreenCounts = data2[:,3]
plt.plot(wavelengthData,GreenCounts,'g',label='data')
plt.savefig('Helium Spectrum4.jpg', format='jpg', dpi=500)

# %%
maxR = np.argmax(data2[:,2])

# %%
print(maxR)
# Out:
# 372

# %%
print(wavelengthData[372])
# Out:
# 545.5
