# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import name 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import math

# %%
data = pd.read_csv('https://spectralworkbench.org/spectrums/latest/239500.csv')

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Hydrogen Spectrum") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Average, color="black",label='average',
         linewidth=1)
plt.savefig('Hydrogen Spectrum.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Hydrogen Spectrum, Red Color") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Red, color="Red",label='Red', 
         linewidth=1)
plt.savefig('Hydrogen Spectrum1.jpg', format='jpg', dpi=500)

# %%
data2 = np.loadtxt("https://spectralworkbench.org/spectrums/latest/239500.csv",delimiter=',',skiprows=1)
print(data)
# Out:
#      Wavelength  Average    Red  Green   Blue
# 0         157.3     20.4  22.95   10.2  28.05
# 1         158.5     20.4  22.95   10.2  28.05
# 2         159.6     20.4  22.95   10.2  25.50
# 3         160.8     20.4  22.95   10.2  25.50
# 4         161.9     20.4  22.95   10.2  25.50
# ..          ...      ...    ...    ...    ...
# 635       893.1     17.8  22.95   10.2  22.95
# 636       894.2     20.4  22.95   10.2  25.50
# 637       895.4     20.4  22.95   10.2  25.50
# 638       896.6     20.4  22.95   10.2  28.05
# 639       897.7     20.4  22.95   10.2  28.05
#
# [640 rows x 5 columns]

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Hydrogen Spectrum, Average Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
averageCounts = data2[:,1]
plt.plot(wavelengthData,averageCounts,'k',label='data')
plt.savefig('Hydrogen Spectrum2.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Hydrogen Spectrum, Red Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
RedCounts = data2[:,2]
plt.plot(wavelengthData,RedCounts,'r',label='data')
plt.savefig('Hydrogen Spectrum3.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Hydrogen Spectrum, Green Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
GreenCounts = data2[:,3]
plt.plot(wavelengthData,GreenCounts,'g',label='data')
plt.savefig('Hydrogen Spectrum4.jpg', format='jpg', dpi=500)

# %%
maxR = np.argmax(data2[:,2])

# %%
print(maxR)
# Out:
# 434

# %%
print(wavelengthData[434])
# Out:
# 660.2
