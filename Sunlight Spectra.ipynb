# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import name 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import math

# %%
data = pd.read_csv('https://spectralworkbench.org/spectrums/latest/169741.csv')

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Sunlight Spectrum") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Average, color="black",label='average',
         linewidth=1)
plt.savefig('Sunlight Spectrum.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Sunlight Spectrum, Red Color") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
plt.plot(data.Wavelength, data.Red, color="Red",label='Red', 
         linewidth=1)
plt.savefig('Sunlight Spectrum1.jpg', format='jpg', dpi=500)

# %%
data2 = np.loadtxt("https://spectralworkbench.org/spectrums/latest/169741.csv",delimiter=',',skiprows=1)
print(data)
# Out:
#      Wavelength  Average    Red  Green   Blue
# 0         382.4     5.10   2.55   2.55  10.20
# 1         382.8     5.10   2.55   2.55  10.20
# 2         383.3     7.65   5.10   5.10  12.75
# 3         383.8     7.65   5.10   5.10  12.75
# 4         384.2    10.20  10.20   5.10  12.75
# ..          ...      ...    ...    ...    ...
# 635       679.8     7.65   5.10   5.10  10.20
# 636       680.2     5.10   2.55   2.55   7.65
# 637       680.7     5.10   2.55   2.55   7.65
# 638       681.2     5.10   2.55   2.55  10.20
# 639       681.6     5.10   2.55   2.55  10.20
#
# [640 rows x 5 columns]

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Sunlight Spectrum, Average Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
averageCounts = data2[:,1]
plt.plot(wavelengthData,averageCounts,'k',label='data')
plt.savefig('Sunlight Spectrum2.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Sunlight Spectrum, Red Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
RedCounts = data2[:,2]
plt.plot(wavelengthData,RedCounts,'r',label='data')
plt.savefig('Sunlight Spectrum3.jpg', format='jpg', dpi=500)

# %%
plt.figure(figsize=(14,9.5), dpi=400)
plt.title("Sunlight Spectrum, Green Counts") 
plt.xlabel("Wavelength (nm)")  
plt.ylabel("Intensity")
wavelengthData = data2[:,0]
GreenCounts = data2[:,3]
plt.plot(wavelengthData,GreenCounts,'g',label='data')
plt.savefig('Sunlight Spectrum4.jpg', format='jpg', dpi=500)

# %%
maxR = np.argmax(data2[:,2])

# %%
print(maxR)
# Out:
# 458

# %%
print(wavelengthData[458])
# Out:
# 596.9
